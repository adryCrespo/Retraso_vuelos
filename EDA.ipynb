# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Variables-numericas" data-toc-modified-id="Variables-numericas-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Variables numericas</a></span></li><li><span><a href="#Variables-categoricas" data-toc-modified-id="Variables-categoricas-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Variables categoricas</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_pickle("../Datos/df.pickle")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168288 entries, 0 to 1178176
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   salida_date             1168288 non-null  datetime64[ns]
#  1   llegada_date            1168288 non-null  datetime64[ns]
#  2   year                    1168288 non-null  int64
#  3   day_of_month            1168288 non-null  int64
#  4   day_of_week             1168288 non-null  int64
#  5   origin_airport_id       1168288 non-null  int64
#  6   dest_airport_id         1168288 non-null  int64
#  7   op_carrier_fl_num       1168288 non-null  int64
#  8   tail_num                1168288 non-null  object
#  9   op_carrier              1168288 non-null  object
#  10  dep_del15               1168288 non-null  float64
#  11  arr_del15               1168288 non-null  float64
#  12  cancelled               1168288 non-null  float64
#  13  diverted                1168288 non-null  float64
#  14  distance                1168288 non-null  float64
#  15  type_org                1168288 non-null  object
#  16  name_org                1168288 non-null  object
#  17  latitude_deg_org        1168288 non-null  float64
#  18  longitude_deg_org       1168288 non-null  float64
#  19  elevation_ft_org        1168241 non-null  float64
#  20  iso_country_org         1168288 non-null  object
#  21  iso_region_org          1168288 non-null  object
#  22  type_lleg               1168288 non-null  object
#  23  name_lleg               1168288 non-null  object
#  24  latitude_deg_lleg       1168288 non-null  float64
#  25  longitude_deg_lleg      1168288 non-null  float64
#  26  elevation_ft_lleg       1168245 non-null  float64
#  27  iso_country_lleg        1168288 non-null  object
#  28  iso_region_lleg         1168288 non-null  object
#  29  duracion_minutos        1158539 non-null  float64
#  30  fecha_salida_date       1168288 non-null  object
#  31  dia_salida_date         1168288 non-null  int64
#  32  hora_salida_date        1168288 non-null  int64
#  33  diasemana_salida_date   1168288 non-null  int64
#  34  fecha_llegada_date      1168288 non-null  object
#  35  dia_llegada_date        1168288 non-null  int64
#  36  hora_llegada_date       1168288 non-null  int64
#  37  diasemana_llegada_date  1168288 non-null  int64
# dtypes: datetime64[ns](2), float64(12), int64(12), object(12)
# memory usage: 347.6+ MB

# %% [markdown]
# # EDA

# %% [markdown]
# ## Variables numericas

# %%
df.select_dtypes('number').hist(figsize=(16,16))
plt.show()

# %% [markdown]
# - Obervaciones:
#     - en distintos años igual numero de vuelos
#     - en los aeropuertos llegadas y salidas parecen iguales, tiene sentido

# %% [markdown]
# Cosas a mirar:
# - duracion minutos: valores altos
# - elevaciones: valores altos
# - distancias: altos
# - a final de mes un incremento numero de vuelos (sera vacaciones??

# %% [markdown]
# **P1** Hay algun cancelado y diverted?

# %%
pd.crosstab(df.diverted, df.cancelled)
# Out:
# cancelled      0.0    1.0
# diverted
# 0.0        1145733  20129
# 1.0           2426      0

# %% [markdown]
# No hay ninguno **cancelado** y **diverted**

# %%
df.select_dtypes('number').describe().T
# Out:
#                             count          mean          std           min  \
# year                    1168288.0   2019.510849     0.499882   2019.000000
# day_of_month            1168288.0     15.970265     8.986618      1.000000
# day_of_week             1168288.0      3.897374     1.916685      1.000000
# origin_airport_id       1168288.0  12664.295117  1527.881207  10135.000000
# dest_airport_id         1168288.0  12664.181918  1527.781228  10135.000000
# op_carrier_fl_num       1168288.0   2591.286039  1822.043266      1.000000
# dep_del15               1168288.0      0.152156     0.359172      0.000000
# arr_del15               1168288.0      0.158411     0.365126      0.000000
# cancelled               1168288.0      0.017229     0.130125      0.000000
# diverted                1168288.0      0.002077     0.045522      0.000000
# distance                1168288.0    799.697414   591.260995     31.000000
# latitude_deg_org        1168288.0     37.313473     5.050185     21.079367
# longitude_deg_org       1168288.0    -93.308022    13.844508   -158.472000
# elevation_ft_org        1168241.0   1071.370413  1217.031134      0.000000
# latitude_deg_lleg       1168288.0     37.314272     5.051453     21.079367
# longitude_deg_lleg      1168288.0    -93.310430    13.844035   -158.472000
# elevation_ft_lleg       1168245.0   1071.890350  1217.915683      0.000000
# duracion_minutos        1158539.0    140.997006   117.383180      0.000000
# dia_salida_date         1168288.0     15.970265     8.986618      1.000000
# hora_salida_date        1168288.0     12.792510     5.208020      0.000000
# diasemana_salida_date   1168288.0      2.897374     1.916685      0.000000
# dia_llegada_date        1168288.0     15.967523     8.983742      1.000000
# hora_llegada_date       1168288.0     14.245950     5.544675      0.000000
# diasemana_llegada_date  1168288.0      2.898204     1.916525      0.000000
#
#                                  25%           50%           75%           max
# year                     2019.000000   2020.000000   2020.000000   2020.000000
# day_of_month                8.000000     16.000000     24.000000     31.000000
# day_of_week                 2.000000      4.000000      5.000000      7.000000
# origin_airport_id       11292.000000  12889.000000  14027.000000  16869.000000
# dest_airport_id         11292.000000  12889.000000  14027.000000  16869.000000
# op_carrier_fl_num        1041.000000   2152.000000   4018.000000   7439.000000
# dep_del15                   0.000000      0.000000      0.000000      1.000000
# arr_del15                   0.000000      0.000000      0.000000      1.000000
# cancelled                   0.000000      0.000000      0.000000      1.000000
# diverted                    0.000000      0.000000      0.000000      1.000000
# distance                  368.000000    639.000000   1041.000000   5095.000000
# latitude_deg_org           33.404643     38.466099     41.055720     70.715599
# longitude_deg_org         -99.865303    -90.461518    -83.723198    -69.244698
# elevation_ft_org          340.000000    678.000000   1280.000000   9710.000000
# latitude_deg_lleg          33.404643     38.466099     41.055720     70.715599
# longitude_deg_lleg        -99.865303    -90.461518    -83.727997    -69.244698
# elevation_ft_lleg         340.000000    678.000000   1280.000000   9710.000000
# duracion_minutos           78.000000    114.000000    170.000000   1439.000000
# dia_salida_date             8.000000     16.000000     24.000000     31.000000
# hora_salida_date            9.000000     13.000000     17.000000     23.000000
# diasemana_salida_date       1.000000      3.000000      4.000000      6.000000
# dia_llegada_date            8.000000     16.000000     24.000000     31.000000
# hora_llegada_date          10.000000     15.000000     19.000000     23.000000
# diasemana_llegada_date      1.000000      3.000000      4.000000      6.000000

# %% [markdown]
# - elevacion: datos a mas de 9000 pies?
# - distancia: 5000 ??
# - duracion: 1400 minutos??

# %% [markdown]
# ## Variables categoricas

# %%
df.select_dtypes(exclude='number').nunique()
# Out:
# salida_date           75729
# llegada_date          80569
# tail_num               5857
# op_carrier               17
# type_org                  5
# name_org                352
# iso_country_org           1
# iso_region_org           44
# type_lleg                 5
# name_lleg               352
# iso_country_lleg          1
# iso_region_lleg          44
# fecha_salida_date        62
# fecha_llegada_date       64
# dtype: int64

# %%
# Todos son vuelos que van y llegan a USA
df.drop(columns=['iso_country_org','iso_country_lleg' ],inplace=True)

# %%
var_cat = df.select_dtypes(exclude='number').columns.tolist()

# %%
from math import ceil
n = ceil(len(var_cat2)/2)

f, ax = plt.subplots(n,2, figsize = (16,n*8)) 
ax = ax.flat 

for i, variable in enumerate(var_cat2):
# f, ax = plt.subplots(n,2, figsize = (12,4))
    df[variable].value_counts(ascending=True).plot.barh(ax=ax[i])
    ax[i].set_title(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12424/1705131314.py in <module>
#       1 from math import ceil
# ----> 2 n = ceil(len(var_cat2)/2)
#       3
#       4 f, ax = plt.subplots(n,2, figsize = (16,n*8))
#       5 ax = ax.flat
#
# NameError: name 'var_cat2' is not defined

# %%
cat = df.select_dtypes(exclude='number').reset_index()
columns_cat = cat.columns[cat.nunique()<20]
cat.loc[:,columns_cat].apply(lambda x: x.value_counts(normalize=True) ).T.stack()\
        .to_frame().reset_index().rename(columns={'level_0':'variable','level_1':'value',0:'frecuencia'})\
        .sort_values(by = ['variable','frecuencia'])
# Out:
#       variable          value  frecuencia
# 8   op_carrier             HA    0.011820
# 7   op_carrier             G4    0.012363
# 6   op_carrier             F9    0.018691
# 5   op_carrier             EV    0.020216
# 10  op_carrier             NK    0.027989
# 15  op_carrier             YV    0.030528
# 2   op_carrier             AS    0.035825
# 0   op_carrier             9E    0.037034
# 11  op_carrier             OH    0.040420
# 3   op_carrier             B6    0.041966
# 9   op_carrier             MQ    0.044219
# 16  op_carrier             YX    0.046848
# 13  op_carrier             UA    0.080761
# 12  op_carrier             OO    0.116277
# 4   op_carrier             DL    0.131183
# 1   op_carrier             AA    0.131210
# 14  op_carrier             WN    0.172653
# 25   type_lleg  seaplane_base    0.001557
# 22   type_lleg    balloonport    0.002909
# 23   type_lleg         closed    0.176363
# 24   type_lleg       heliport    0.358240
# 26   type_lleg  small_airport    0.460930
# 20    type_org  seaplane_base    0.001554
# 17    type_org    balloonport    0.002907
# 18    type_org         closed    0.176419
# 19    type_org       heliport    0.358233
# 21    type_org  small_airport    0.460887

# %% [markdown]
# - La mayoria de aerolineas tienen un numero parecido de vuelos
# - type: son hay bastantes heliopuertos, y no hay grandes aeropuertos
